# %% [markdown]
# # Project 1: Galaxy Zoo

# %%
from fastai.vision import *

# %%
from galaxy import GalaxyOutput

# %%
import pandas as pd

# %%
#path = Config.data_path() / 'galaxyzoo'
path = Path('/storage') / 'galaxyzoo'

# %%
path.ls()
# Out:
# [PosixPath('/storage/galaxyzoo/all_ones_benchmark.zip'),
#  PosixPath('/storage/galaxyzoo/all_ones_benchmark.csv'),
#  PosixPath('/storage/galaxyzoo/central_pixel_benchmark.csv'),
#  PosixPath('/storage/galaxyzoo/images_training_rev1.zip'),
#  PosixPath('/storage/galaxyzoo/training_solutions_rev1.zip'),
#  PosixPath('/storage/galaxyzoo/images_test_rev1'),
#  PosixPath('/storage/galaxyzoo/images_test_rev1.zip'),
#  PosixPath('/storage/galaxyzoo/images_training_rev1'),
#  PosixPath('/storage/galaxyzoo/central_pixel_benchmark.zip'),
#  PosixPath('/storage/galaxyzoo/all_zeros_benchmark.csv'),
#  PosixPath('/storage/galaxyzoo/all_zeros_benchmark.zip'),
#  PosixPath('/storage/galaxyzoo/training_solutions_rev1.csv'),
#  PosixPath('/storage/galaxyzoo/models')]

# %% [markdown]
# __How to load the data__
#
# - Data is in a folder
# - Data is split by folder into train and test
# - For training we maybe just split the train dataset by percentage and leave their test set as a genuine hold-out set.
# - the labels are found in csv files for train and test
# - the labels are actually a categorial distribution of user responses to the the images so we have to either take the max of that or we could even set the vector as the objective. Both would be interesting experiments.
# - Data augmentation - flipping and rotating and warping should be okay. warping perhaps not.

# %%
tfms = get_transforms(flip_vert=True, max_warp=0.0, xtra_tfms=rand_pad(10, 128))

# %%
type(tfms)
# Out:
# tuple

# %%
labels = pd.read_csv(path/'training_solutions_rev1.csv')

# %%
labels.head()
# Out:
#    GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0    100008  0.383147  0.616853  0.000000  0.000000  0.616853  0.038452
# 1    100023  0.327001  0.663777  0.009222  0.031178  0.632599  0.467370
# 2    100053  0.765717  0.177352  0.056931  0.000000  0.177352  0.000000
# 3    100078  0.693377  0.238564  0.068059  0.000000  0.238564  0.109493
# 4    100090  0.933839  0.000000  0.066161  0.000000  0.000000  0.000000
#
#    Class3.2  Class4.1  Class4.2    ...      Class9.3  Class10.1  Class10.2  \
# 0  0.578401  0.418398  0.198455    ...      0.000000   0.279952   0.138445
# 1  0.165229  0.591328  0.041271    ...      0.018764   0.000000   0.131378
# 2  0.177352  0.000000  0.177352    ...      0.000000   0.000000   0.000000
# 3  0.129071  0.189098  0.049466    ...      0.000000   0.094549   0.000000
# 4  0.000000  0.000000  0.000000    ...      0.000000   0.000000   0.000000
#
#    Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  Class11.6
# 0   0.000000   0.000000   0.092886        0.0        0.0        0.0   0.325512
# 1   0.459950   0.000000   0.591328        0.0        0.0        0.0   0.000000
# 2   0.000000   0.000000   0.000000        0.0        0.0        0.0   0.000000
# 3   0.094549   0.189098   0.000000        0.0        0.0        0.0   0.000000
# 4   0.000000   0.000000   0.000000        0.0        0.0        0.0   0.000000
#
# [5 rows x 38 columns]

# %%
src = (ImageList.from_csv(path,
                           'training_solutions_rev1.csv', 
                           folder='images_training_rev1', 
                           suffix='.jpg',
                           cols=0,)
            .split_by_rand_pct(0.2)
            .label_from_df(cols=list(range(1, 38)), label_cls=FloatList))
data = (src.transform(tfms, size=128)
           .databunch()).normalize(imagenet_stats)

# %%
tfms[1]
# Out:
# [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)]

# %%
tfms_flat = list(itertools.chain.from_iterable(tfms))

# %%
len(tfms_flat)
# Out:
# 9

# %%
fig, axes = plt.subplots(nrows=len(tfms_flat), ncols=5, figsize=(15, 15))

for i, tfm in enumerate(tfms_flat):
    for j in range(5):
        ax = axes[i, j]
        img = data.train_ds[3][0].apply_tfms(tfm)
        img.show(ax=ax)

# %%
data.show_batch(3)
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/matplotlib/tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '

# %%
learner = cnn_learner(data, models.resnet50, metrics=rmse, ps=0.3)
learner.model[-1] = nn.Sequential(*learner.model[-1], GalaxyOutput())

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-2

# %%
learner.fit_one_cycle(2, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.012811</td>
#       <td>0.011862</td>
#       <td>0.108761</td>
#       <td>02:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.010659</td>
#       <td>0.010126</td>
#       <td>0.100450</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('stage-resnet50-1')

# %%
learner.unfreeze()

# %%
learner.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.recorder.plot()

# %%
learner.fit_one_cycle(5, slice(1e-5, 5e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 13:28<03:22]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.010169</td>
#       <td>0.009776</td>
#       <td>0.098713</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.009323</td>
#       <td>0.009742</td>
#       <td>0.098543</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.008841</td>
#       <td>0.008213</td>
#       <td>0.090485</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.008242</td>
#       <td>0.008007</td>
#       <td>0.089348</td>
#       <td>03:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='486' class='' max='769', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.20% [486/769 01:52<01:05 0.0080]
#     </div>

# %%
learner.save('stage-resnet50-2')

# %%
learner.load('stage-resnet50-2');

# %%
tfms = get_transforms(flip_vert=True, max_warp=0.0, xtra_tfms=rand_pad(6, 224))

# %%
data = (src.transform(tfms, size=224)
        .databunch().normalize(imagenet_stats))

learner.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
learner.freeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-3

# %%
learner.fit_one_cycle(2, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008168</td>
#       <td>0.007843</td>
#       <td>0.088435</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.007863</td>
#       <td>0.007662</td>
#       <td>0.087405</td>
#       <td>06:43</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-4

# %%
learner.fit_one_cycle(5, slice(1e-5, lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.007818</td>
#       <td>0.007477</td>
#       <td>0.086341</td>
#       <td>08:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.007747</td>
#       <td>0.007572</td>
#       <td>0.086889</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.007394</td>
#       <td>0.007030</td>
#       <td>0.083727</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.006955</td>
#       <td>0.006827</td>
#       <td>0.082498</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.007053</td>
#       <td>0.006746</td>
#       <td>0.082007</td>
#       <td>08:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('stage-resnet50-224-3')

# %%
learner.fit_one_cycle(5, slice(1e-5/2, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.006831</td>
#       <td>0.006748</td>
#       <td>0.082021</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.006756</td>
#       <td>0.006794</td>
#       <td>0.082296</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006822</td>
#       <td>0.006681</td>
#       <td>0.081610</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.006793</td>
#       <td>0.006595</td>
#       <td>0.081081</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.006869</td>
#       <td>0.006604</td>
#       <td>0.081138</td>
#       <td>08:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.validate()
# Out:
# [0.0066041066, tensor(0.0811)]

# %%
learner.save('stage-resnet50-224-4')

# %% [markdown]
# ## Train Full Res

# %%
tfms = get_transforms(flip_vert=True, max_warp=0.0, xtra_tfms=rand_pad(16, 424))

# %%
data = (src.transform(tfms, size=424)
        .databunch(bs=20).normalize(imagenet_stats))

#learner.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 424, 424])

# %%
learner = cnn_learner(data, models.resnet50, metrics=rmse, ps=0.3)
learner.model[-1] = nn.Sequential(*learner.model[-1], GalaxyOutput())

# %%
learner.load('stage-resnet50-224-4');

# %%
learner.freeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-3

# %%
learner.fit_one_cycle(2, slice(lr))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 25:09<25:09]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008267</td>
#       <td>0.007158</td>
#       <td>0.084190</td>
#       <td>25:09</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='2463', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-7807e15d0680> in <module>
# ----> 1 learner.fit_one_cycle(2, slice(lr))
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     197         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     198         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 199         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     200
#     201     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      28
#      29     if not loss_func: return to_detach(out), yb[0].detach()
# ---> 30     loss = loss_func(out, *yb)
#      31
#      32     if opt is not None:
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/layers.py in __call__(self, input, target, **kwargs)
#     265         if self.floatify: target = target.float()
#     266         input = input.view(-1,input.shape[-1]) if self.is_2d else input.view(-1)
# --> 267         return self.func.__call__(input, target.view(-1), **kwargs)
#     268
#     269 def CrossEntropyFlat(*args, axis:int=-1, **kwargs):
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     433     @weak_script_method
#     434     def forward(self, input, target):
# --> 435         return F.mse_loss(input, target, reduction=self.reduction)
#     436
#     437
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    2154     else:
#    2155         expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2156         ret = torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2157     return ret
#    2158
#
# KeyboardInterrupt:

# %%
learner.save('stage-resnet50-424-1')

# %%
learner.load('stage-resnet50-424-1');

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.fit_one_cycle(2, slice(1e-5, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.008230</td>
#       <td>0.007085</td>
#       <td>0.083833</td>
#       <td>32:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.007410</td>
#       <td>0.006627</td>
#       <td>0.081070</td>
#       <td>32:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('stage-resnet50-424-2')
